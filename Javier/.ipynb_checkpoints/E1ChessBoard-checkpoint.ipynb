ma/asamma.14.jpg', 'input/faces94/female/asamma/asamma.15.jpg', 'input/faces94/female/asamma/asamma.16.jpg', 'input/faces94/female/asamma/asamma.17.jpg', 'input/faces94/female/asamma/asamma.18.jpg', 'input/faces94/female/asamma/asamma.19.jpg', 'input/faces94/female/asamma/asamma.2.jpg', 'input/faces94/female/asamma/asamma.20.jpg', 'input/faces94/female/asamma/asamma.3.jpg', 'input/faces94/female/asamma/asamma.4.jpg', 'input/faces94/female/asamma/asamma.5.jpg', 'input/faces94/female/asamma/asamma.6.jpg', 'input/faces94/female/asamma/asamma.7.jpg', 'input/faces94/female/asamma/asamma.8.jpg', 'input/faces94/female/asamma/asamma.9.jpg', 'input/faces94/female/asewil/asewil.1.jpg', 'input/faces94/female/asewil/asewil.10.jpg', 'input/faces94/female/asewil/asewil.11.jpg', 'input/faces94/female/asewil/asewil.12.jpg', 'input/faces94/female/asewil/asewil.13.jpg', 'input/faces94/female/asewil/asewil.14.jpg', 'input/faces94/female/asewil/asewil.15.jpg', 'input/faces94/female/asewil/asewil.16.jp ...

# %%
image = cv2.resize(cv2.imread(image_list[2500]),(180, 180)) 
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
plt.imshow(image, cmap = plt.cm.gray)

# %%
# Make a whole matrix with all dataset 180x180*num_images
distance_cheb = []
for image in range(len(image_list)):
    
    dis=dist.chebyshev(np.concatenate(cv2.cvtColor(cv2.resize(cv2.imread(image_list[image]),(180, 180)),cv2.COLOR_BGR2GRAY)), med_f)
    #distance_cheb.append(dis)
    distance_cheb.insert(len(image_list),dis)

# %%
print(len(distance_cheb))
# Out:
# 3059

# %%
plt.hist(distance_cheb, bins='auto')  # arguments are passed to np.histogram
plt.title("distancia vs la media")
plt.show()

# %%
# Make a whole matrix with all dataset 180x180*num_images
data_set=np.zeros((180,180,len(image_list)))
for image in range(len(image_list)):
    
    data_set[:,:,image]=cv2.cvtColor(cv2.resize(cv2.imread(image_list[image]),(180, 180)),cv2.COLOR_BGR2GRAY)
    
plt.imshow(data_set[:,:,2500], cmap = plt.cm.gray) #check

# %%
mean_face=np.mean(data_set, axis=2)
plt.imshow(mean_face, cmap = plt.cm.gray) #check

# %%
median_face=np.median(data_set, axis=2)
plt.imshow(median_face, cmap = plt.cm.gray) #check

# %%
import scipy.spatial.distance as dist

# %%
print(data_set.shape)
# Out:
# (180, 180, 3059)

# %%
dataarray = np.squeeze(np.asarray(mean_face))
print(mean_face)
print('=============================')

m_f =np.concatenate(mean_face)
med_f =np.concatenate(median_face)

#print(m_f)
dist.chebyshev(m_f, med_f)
# Out:
# [[121.47466492 121.68649886 121.92317751 ... 123.04151684 122.86335404
#   122.66884603]
#  [123.38084341 123.60509971 123.84243217 ... 124.66132723 124.4338019
#   124.16999019]
#  [123.27819549 123.42497548 123.55475646 ... 124.31121281 124.11474338
#   123.8685845 ]
#  ...
#  [ 89.09414841  88.88166067  88.73030402 ...  81.56031383  81.93167702
#    81.97809742]
#  [ 89.9532527   89.60836875  89.2245832  ...  81.86891141  82.44132069
#    82.55148741]
#  [ 89.78130108  89.19058516  88.47629944 ...  81.12291599  81.91337038
#    82.09153318]]
# =============================
# 35.24387054593004

# %%
print(data_set.shape)
# Out:
# (180, 180, 3059)

# %%
# Make a whole matrix with all dataset 180x180*num_images
distance_cheb_mode = []
for image in range(len(image_list)):
    
    dis2=dist.chebyshev(np.concatenate(cv2.cvtColor(cv2.resize(cv2.imread(image_list[image]),(180, 180)),cv2.COLOR_BGR2GRAY)), m_f)
    #distance_cheb.append(dis)
    distance_cheb_mode.insert(len(image_list),dis2)
